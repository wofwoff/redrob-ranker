# %% [markdown]
# # Redrob Ranker Sandbox
#
# This sandbox demonstrates the **Redrob Ranker** algorithm for the **Intelligent Candidate Discovery & Ranking Challenge**.
#
# It clones the repository, installs the required dependencies, runs the ranker script on a sample of 50 candidates (`data/sample.jsonl`), and prints the top ranked candidates.
#
# ---

# %% [markdown]
# ### Step 1: Clone Repository and Install Dependencies

# %%
# Clone the repository
# !git clone https://github.com/wofwoff/redrob-ranker.git

# Change directory into the repo
# %cd redrob-ranker

# Install dependencies (pure numpy + scipy)
# !pip install -r requirements.txt

# %% [markdown]
# ### Step 2: Run the Ranker on the Sample Candidate Dataset

# %%
# Run the ranker on data/sample.jsonl and output to sample_submission.csv
# !python rank.py --candidates data/sample.jsonl --out sample_submission.csv

# %% [markdown]
# ### Step 3: Inspect the Top Results

# %%
import pandas as pd

# Load and display the generated CSV
df = pd.read_csv("sample_submission.csv")
pd.set_option('display.max_colwidth', None)
df.head(20)
